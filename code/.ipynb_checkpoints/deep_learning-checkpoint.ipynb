# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Project 5: Deep Learning Capstone - SVHN Number Recognition

# %% [markdown]
# Import libraries and dependencies.

# %%
# %matplotlib inline
from __future__ import print_function
import matplotlib.pyplot as plt
import tensorflow as tf
import scipy.io as io
import numpy as np
import csv

import os
from datetime import datetime

# %% [markdown]
# Load data.

# %%
train_data = io.loadmat("../data/train_32x32.mat")
test_data = io.loadmat("../data/test_32x32.mat")

train_dataset = train_data['X']
train_labels = train_data['y']
test_dataset = test_data['X']
test_labels = test_data['y']

print('Training set', train_dataset.shape, train_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (32, 32, 3, 73257) (73257, 1)
# Test set (32, 32, 3, 26032) (26032, 1)

# %% [markdown]
# Reformat data to a friendly shape to Tensorflow.

# %%
IMAGE_SIZE = 32
NUM_CLASSES = 10
NUM_CHANNELS = 1
NUM_TRAIN_DATA = 73000

def reformat(dataset, labels):
    dataset = np.transpose(dataset, (3, 0, 1, 2)).astype(np.float32)
    one_hot_labels = []
    for label in labels:
        one_hot_label = np.zeros(NUM_CLASSES, np.float32)
        if label[0] == 10:
            one_hot_label[0] = 1.0
        else:
            one_hot_label[label[0]] = 1.0
        one_hot_labels.append(one_hot_label)
    labels = np.array(one_hot_labels).astype(np.float32)
    return dataset, labels

valid_dataset = train_dataset[:, :, :, NUM_TRAIN_DATA : ]
valid_labels = train_labels[NUM_TRAIN_DATA : ]
train_dataset = train_dataset[:, :, :, : NUM_TRAIN_DATA]
train_labels = train_labels[ : NUM_TRAIN_DATA]

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (73000, 32, 32, 3) (73000, 10)
# Validation set (257, 32, 32, 3) (257, 10)
# Test set (26032, 32, 32, 3) (26032, 10)

# %% [markdown]
# Show input images.

# %%
plt.rcParams['figure.figsize'] = (15.0, 15.0)
f, ax = plt.subplots(nrows=1, ncols=10)

picked = np.zeros(10, int)
count = np.zeros(10, int)
cnt = 0
while cnt != 10:
    idx = np.random.randint(0, train_dataset.shape[0] - 1)
    lab = np.argmax(train_labels[idx])
    if count[lab] == 0:
        count[lab] = 1
        picked[lab] = idx
        cnt += 1


for i in range(10):
    ax[i].axis('off')
    ax[i].set_title(np.argmax(train_labels[picked[i]]), loc='center')
    ax[i].imshow(train_dataset[picked[i]])

# %% [markdown]
# Normalization operation.

# %%
def normalize(dataset):
    new_dataset = np.add.reduce(dataset, keepdims=True, axis=3)
    new_dataset = new_dataset / 3.0
    return new_dataset / 128.0 - 1.0

new_train_dataset = normalize(train_dataset)
new_valid_dataset = normalize(valid_dataset)
new_test_dataset = normalize(test_dataset)

print('Training set', new_train_dataset.shape, train_labels.shape)
print('Validation set', new_valid_dataset.shape, valid_labels.shape)
print('Test set', new_test_dataset.shape, test_labels.shape)
# Out:
# Training set (73000, 32, 32, 1) (73000, 10)
# Validation set (257, 32, 32, 1) (257, 10)
# Test set (26032, 32, 32, 1) (26032, 10)

# %% [markdown]
# Plot normalized images.

# %%
f, ax = plt.subplots(nrows=1, ncols=10)
for i in range(10):
    ax[i].axis('off')
    ax[i].set_title(np.argmax(train_labels[picked[i]]), loc='center')
    ax[i].imshow(new_train_dataset[picked[i]].squeeze())

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Set hyper-parameters.

# %%
batch_size = 64
conv1_depth = 16
conv2_depth = 32
hidden_layer_size = 64
patch_size = 5
start_learning_rate = 0.001
regularization_lambda = 0.0005
dropout_rate = 0.9
learning_rate_decay_rate = 0.99

# %% [markdown]
# ConvNet setting.

# %%
graph = tf.Graph()
with graph.as_default():
    tf_train_dataset = tf.placeholder(tf.float32, shape = (batch_size, IMAGE_SIZE, IMAGE_SIZE, NUM_CHANNELS))
    tf_train_labels = tf.placeholder(tf.float32, shape = (batch_size, NUM_CLASSES))
    tf_valid_dataset = tf.constant(new_valid_dataset)
    tf_test_dataset = tf.constant(new_test_dataset)

    conv1_filter = tf.Variable(tf.truncated_normal([patch_size, patch_size, NUM_CHANNELS, conv1_depth], stddev = 0.1))
    conv1_biases = tf.Variable(tf.zeros([conv1_depth]))

    conv2_filter = tf.Variable(tf.truncated_normal([patch_size, patch_size, conv1_depth, conv2_depth], stddev = 0.1))
    conv2_biases = tf.Variable(tf.constant(1.0, shape = [conv2_depth]))
    
    layer3_weights = tf.Variable(tf.truncated_normal([IMAGE_SIZE // 4 * IMAGE_SIZE // 4 * conv2_depth, hidden_layer_size], stddev = 0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape = [hidden_layer_size]))
    
    layer4_weights = tf.Variable(tf.truncated_normal([hidden_layer_size, NUM_CLASSES], stddev = 0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape = [NUM_CLASSES]))

    def model(dataset, train = False):
        conv = tf.nn.conv2d(dataset, conv1_filter, [1, 1, 1, 1], padding = 'SAME')
        hidden = tf.nn.relu(conv + conv1_biases)
        hidden = tf.nn.max_pool(hidden, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'SAME')

        conv = tf.nn.conv2d(hidden, conv2_filter, [1, 1, 1, 1], padding = 'SAME')
        hidden = tf.nn.relu(conv + conv2_biases)
        hidden = tf.nn.max_pool(hidden, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'SAME')
    
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        
        if train:
            hidden = tf.nn.dropout(hidden, dropout_rate)

        return tf.matmul(hidden, layer4_weights) + layer4_biases

    logits = model(tf_train_dataset, True)

    regularization = regularization_lambda * \
        (tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer3_biases)
        + tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(layer4_biases))
    
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels)) \
        + regularization

    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(start_learning_rate, 
                                                global_step * batch_size, 
                                                100, 
                                                learning_rate_decay_rate,
                                                staircase = True)
    
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)
    
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))
    
    saver = tf.train.Saver(tf.all_variables())

# %%
NUM_STEPS = 10001

start_time = None
end_time = None
prev_time = None
cur_time = None

with tf.Session(graph = graph) as session:
    tf.initialize_all_variables().run()
    with open('../model/stats_1.csv', 'w') as statsfile:
        statswriter = csv.writer(statsfile, delimiter = ',')
        
        start_time = datetime.now()
        statswriter.writerow([start_time])
        
        prev_time = datetime.now()
        for step in range(NUM_STEPS):
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            batch_dataset = new_train_dataset[offset : (offset + batch_size), :, :, :]
            batch_labels = train_labels[offset : (offset + batch_size), :]
            feed_dict = {tf_train_dataset : batch_dataset, tf_train_labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict = feed_dict)
            if (step % 50 == 0):
                cur_time = datetime.now()
                print('time cost: ', cur_time - prev_time)
                prev_time = cur_time

                batch_accuracy = accuracy(predictions, batch_labels)
                valid_accuracy = accuracy(valid_prediction.eval(), valid_labels)
                
                if (step % 500 == 0):
                    print('Minibatch loss at step %d: %f' % (step, l))
                    print('Minibatch accuracy: %.1f%%' % (batch_accuracy))
                    print('Validation accuracy: %.1f%%' % (valid_accuracy))
                
                statswriter.writerow([cur_time - prev_time, step, batch_accuracy, valid_accuracy, l])
        
        test_accuracy = accuracy(test_prediction.eval(), test_labels)
        print('Test accuracy: %.1f%%' % (test_accuracy))
        statswriter.writerow(['test_accuracy', test_accuracy])
        
        end_time = datetime.now()
        print('Total time cost: ', end_time - start_time)
        statswriter.writerow(['time cost: ', end_time - start_time])
        
        save_path = saver.save(session, "../model/CNN_1.ckpt")
        print("Model saved in file: %s" % save_path)
# Out:
# time cost:  0:00:00.155717
# Minibatch loss at step 0: 4.556162
# Minibatch accuracy: 6.2%
# Validation accuracy: 13.2%
# time cost:  0:00:06.089502
# time cost:  0:00:08.551624
# time cost:  0:00:08.283053
# time cost:  0:00:07.385628
# time cost:  0:00:07.279452
# time cost:  0:00:06.308533
# time cost:  0:00:06.194561
# time cost:  0:00:06.021641
# time cost:  0:00:08.710539
# time cost:  0:00:06.832052
# Minibatch loss at step 500: 1.465371
# Minibatch accuracy: 64.1%
# Validation accuracy: 60.7%
# time cost:  0:00:06.883291
# time cost:  0:00:07.828766
# time cost:  0:00:05.836938
# time cost:  0:00:06.686850
# time cost:  0:00:07.475714
# time cost:  0:00:06.659590
# time cost:  0:00:07.080598
# time cost:  0:00:06.732660
# time cost:  0:00:06.873791
# time cost:  0:00:07.479244
# Minibatch loss at step 1000: 0.882572
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.4%
# time cost:  0:00:05.843071
# time cost:  0:00:05.738994
# time cost:  0:00:05.690331
# time cost:  0:00:05.727180
# time cost:  0:00:05.716506
# time cost:  0:00:05.849003
# time cost:  0:00:05.859544
# time cost:  0:00:05.851063
# time cost:  0:00:05.738858
# time cost:  0:00:05.712461
# Minibatch loss at step 1500: 0.690654
# Minibatch accuracy: 82.8%
# Validation accuracy: 80.2%
# time cost:  0:00:05.657258
# time cost:  0:00:05.686020
# time cost:  0:00:05.698229
# time cost:  0:00:05.708545
# time cost:  0:00:05.759542
# time cost:  0:00:05.701047
# time cost:  0:00:05.740143
# time cost:  0:00:05.761511
# time cost:  0:00:05.852507
# time cost:  0:00:05.752493
# Minibatch loss at step 2000: 0.706740
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
# time cost:  0:00:06.400511
# time cost:  0:00:07.488022
# time cost:  0:00:06.372207
# time cost:  0:00:06.287163
# time cost:  0:00:06.285606
# time cost:  0:00:05.961924
# time cost:  0:00:05.925921
# time cost:  0:00:05.737532
# time cost:  0:00:05.877989
# time cost:  0:00:05.676688
# Minibatch loss at step 2500: 0.847654
# Minibatch accuracy: 76.6%
# Validation accuracy: 83.3%
# time cost:  0:00:05.673115
# time cost:  0:00:05.662204
# time cost:  0:00:05.642620
# time cost:  0:00:05.656425
# time cost:  0:00:05.654618
# time cost:  0:00:05.638913
# time cost:  0:00:05.694866
# time cost:  0:00:05.690247
# time cost:  0:00:05.648691
# time cost:  0:00:05.655466
# Minibatch loss at step 3000: 0.562671
# Minibatch accuracy: 78.1%
# Validation accuracy: 85.6%
# time cost:  0:00:05.667871
# time cost:  0:00:05.670213
# time cost:  0:00:05.739590
# time cost:  0:00:07.557748
# time cost:  0:00:10.449751
# time cost:  0:00:08.883825
# time cost:  0:00:05.758076
# time cost:  0:00:05.700791
# time cost:  0:00:05.708739
# time cost:  0:00:06.467439
# Minibatch loss at step 3500: 0.733655
# Minibatch accuracy: 79.7%
# Validation accuracy: 85.2%
# time cost:  0:00:06.991634
# time cost:  0:00:05.688795
# time cost:  0:00:05.743354
# time cost:  0:00:05.793240
# time cost:  0:00:08.271996
# time cost:  0:00:06.117461
# time cost:  0:00:05.673763
# time cost:  0:00:06.767446
# time cost:  0:00:05.858896
# time cost:  0:00:05.674406
# Minibatch loss at step 4000: 0.439118
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# time cost:  0:00:05.706392
# time cost:  0:00:05.707583
# time cost:  0:00:05.699370
# time cost:  0:00:05.689462
# time cost:  0:00:05.758834
# time cost:  0:00:05.913563
# time cost:  0:00:05.719774
# time cost:  0:00:05.896724
# time cost:  0:00:05.704359
# time cost:  0:00:05.655474
# Minibatch loss at step 4500: 0.243662
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.6%
# time cost:  0:00:06.311221
# time cost:  0:00:05.924245
# time cost:  0:00:06.440114
# time cost:  0:00:05.693755
# time cost:  0:00:05.690854
# time cost:  0:00:06.125058
# time cost:  0:00:05.689146
# time cost:  0:00:05.701944
# time cost:  0:00:05.671021
# time cost:  0:00:05.981446
# Minibatch loss at step 5000: 0.346434
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# time cost:  0:00:05.649451
# time cost:  0:00:05.671200
# time cost:  0:00:05.631685
# time cost:  0:00:05.618846
# time cost:  0:00:05.675191
# time cost:  0:00:06.164687
# time cost:  0:00:05.729555
# time cost:  0:00:05.671722
# time cost:  0:00:05.686852
# time cost:  0:00:05.693612
# Minibatch loss at step 5500: 0.398193
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.0%
# time cost:  0:00:05.691701
# time cost:  0:00:05.680955
# time cost:  0:00:05.677522
# time cost:  0:00:05.668843
# time cost:  0:00:05.688222
# time cost:  0:00:06.265027
# time cost:  0:00:05.696662
# time cost:  0:00:05.746679
# time cost:  0:00:05.752385
# time cost:  0:00:05.671670
# Minibatch loss at step 6000: 0.303929
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.4%
# time cost:  0:00:05.875432
# time cost:  0:00:05.832714
# time cost:  0:00:05.729298
# time cost:  0:00:05.658156
# time cost:  0:00:05.653231
# time cost:  0:00:05.674122
# time cost:  0:00:05.789214
# time cost:  0:00:05.620947
# time cost:  0:00:05.677899
# time cost:  0:00:05.721443
# Minibatch loss at step 6500: 0.391336
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.0%
# time cost:  0:00:05.672104
# time cost:  0:00:05.668048
# time cost:  0:00:05.675812
# time cost:  0:00:06.068078
# time cost:  0:00:05.612099
# time cost:  0:00:05.659914
# time cost:  0:00:05.646569
# time cost:  0:00:05.958843
# time cost:  0:00:05.934991
# time cost:  0:00:06.669612
# Minibatch loss at step 7000: 0.461101
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# time cost:  0:00:07.814115
# time cost:  0:00:05.701603
# time cost:  0:00:06.604170
# time cost:  0:00:06.517077
# time cost:  0:00:05.749484
# time cost:  0:00:05.818996
# time cost:  0:00:05.893886
# time cost:  0:00:05.771801
# time cost:  0:00:05.798640
# time cost:  0:00:05.770167
# Minibatch loss at step 7500: 0.342313
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# time cost:  0:00:05.727178
# time cost:  0:00:05.770206
# time cost:  0:00:05.741779
# time cost:  0:00:05.724731
# time cost:  0:00:05.737088
# time cost:  0:00:05.689032
# time cost:  0:00:05.672362
# time cost:  0:00:05.701699
# time cost:  0:00:05.690830
# time cost:  0:00:06.208798
# Minibatch loss at step 8000: 0.352296
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.4%
# time cost:  0:00:06.399364
# time cost:  0:00:05.753255
# time cost:  0:00:05.937729
# time cost:  0:00:05.735246
# time cost:  0:00:05.698756
# time cost:  0:00:05.709194
# time cost:  0:00:05.713594
# time cost:  0:00:06.698462
# time cost:  0:00:05.760184
# time cost:  0:00:05.783475
# Minibatch loss at step 8500: 0.256893
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# time cost:  0:00:05.708960
# time cost:  0:00:05.670334
# time cost:  0:00:05.714035
# time cost:  0:00:05.678822
# time cost:  0:00:06.248011
# time cost:  0:00:05.757827
# time cost:  0:00:05.745599
# time cost:  0:00:05.704492
# time cost:  0:00:05.746217
# time cost:  0:00:05.735593
# Minibatch loss at step 9000: 0.495474
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.7%
# time cost:  0:00:07.371562
# time cost:  0:00:06.478022
# time cost:  0:00:05.716059
# time cost:  0:00:05.671955
# time cost:  0:00:05.644210
# time cost:  0:00:05.672485
# time cost:  0:00:05.668907
# time cost:  0:00:05.815450
# time cost:  0:00:05.672815
# time cost:  0:00:05.743806
# Minibatch loss at step 9500: 0.321719
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.9%
# time cost:  0:00:05.785643
# time cost:  0:00:05.939183
# time cost:  0:00:05.705020
# time cost:  0:00:05.661913
# time cost:  0:00:05.686472
# time cost:  0:00:05.643901
# time cost:  0:00:05.697962
# time cost:  0:00:05.676413
# time cost:  0:00:05.695166
# time cost:  0:00:05.644878
# Minibatch loss at step 10000: 0.334104
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Test accuracy: 88.3%
# Total time cost:  0:21:16.987649
# Model saved in file: 1_20.ckpt
